# %% [markdown]
# The California housing dataset provides various features related to housing, and there are several interesting questions you can explore for a project:
#
# 1. What is the distribution of median house values?
#
# 2. Analyze the range, mean, and distribution of the 'median_house_value' column to understand the overall pricing trend.
# How does the median income correlate with the median house value?
#
# 3. Investigate the relationship between 'median_income' and 'median_house_value' to understand if higher incomes correspond to higher house values.
# Which areas have the highest and lowest median house values?
#
# 4. Identify geographical regions with the highest and lowest median house values by analyzing 'longitude' and 'latitude'.
# Is there a correlation between housing age and median house value?
#
# 5. Explore if there's a relationship between 'housing_median_age' and 'median_house_value' to determine if newer or older houses tend to have higher values.
# How does the housing density (population per household) vary across different regions?
#
# 6. Calculate the housing density by dividing 'population' by 'households' and analyze its distribution across different areas.
# What is the correlation between the number of rooms and median house value?
#
# 7. Investigate if 'total_rooms' has a correlation with 'median_house_value' to understand how the size of the houses influences their values.
# Are there any patterns in the distribution of total bedrooms and total rooms?
#
# 8. Examine if there's a consistent ratio or pattern between 'total_bedrooms' and 'total_rooms' across different houses.
# How does the population relate to housing density?
#
# 9. Explore the relationship between 'population' and the housing density to understand if higher population areas have higher or lower housing density.
# 10. What is the overall distribution of housing ages in the dataset?
#
# 11. Visualize the distribution of 'housing_median_age' to identify common age ranges for houses in the dataset.
# Is there a correlation between location (longitude and latitude) and housing features/values?
#
# 12. Analyze if specific regions (defined by 'longitude' and 'latitude') exhibit particular housing characteristics or values.
# These questions can serve as a starting point for your project and help you gain insights into various aspects of the California housing market.

# %%
help(os)
# Out:
# Help on module os:
#
# NAME
#     os - OS routines for NT or Posix depending on what system we're on.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/os.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This exports:
#       - all functions from posix or nt, e.g. unlink, stat, etc.
#       - os.path is either posixpath or ntpath
#       - os.name is either 'posix' or 'nt'
#       - os.curdir is a string representing the current directory (always '.')
#       - os.pardir is a string representing the parent directory (always '..')
#       - os.sep is the (or a most common) pathname separator ('/' or '\\')
#       - os.extsep is the extension separator (always '.')
# ...

# %%
help(plt)
# Out:
# Help on module matplotlib.pyplot in matplotlib:
#
# NAME
#     matplotlib.pyplot
#
# DESCRIPTION
#     `matplotlib.pyplot` is a state-based interface to matplotlib. It provides
#     an implicit,  MATLAB-like, way of plotting.  It also opens figures on your
#     screen, and acts as the figure GUI manager.
#
#     pyplot is mainly intended for interactive plots and simple cases of
#     programmatic plot generation::
#
#         import numpy as np
#         import matplotlib.pyplot as plt
#
#         x = np.arange(0, 5, 0.1)
#         y = np.sin(x)
#         plt.plot(x, y)
#
#     The explicit object-oriented API is recommended for complex plots, though
#     pyplot is still usually used to create the figure and often the axes in the
#     figure. See `.pyplot.figure`, `.pyplot.subplots`, and
#     `.pyplot.subplot_mosaic` to create figures, and
#     :doc:`Axes API </api/axes_api>` for the plotting methods on an Axes::
#
#         import numpy as np
# ...

# %%
help(sns)
# Out:
# Help on package seaborn:
#
# NAME
#     seaborn - # Import seaborn objects
#
# PACKAGE CONTENTS
#     _compat
#     _core (package)
#     _decorators
#     _docstrings
#     _marks (package)
#     _oldcore
#     _statistics
#     _stats (package)
#     _testing
#     algorithms
#     axisgrid
#     categorical
#     cm
#     colors (package)
#     distributions
#     external (package)
#     matrix
#     miscplot
#     objects
#     palettes
#     rcmod
#     regression
#     relational
#     utils
#     widgets
#
# DATA
#     crayons = {'Almond': '#EFDECD', 'Antique Brass': '#CD9575', 'Apricot':...
#     xkcd_rgb = {'acid green': '#8ffe09', 'adobe': '#bd6c48', 'algae': '#54...
#
# VERSION
#     0.12.2
#
# FILE
#     c:\users\dell\anaconda3\lib\site-packages\seaborn\__init__.py

# %% [markdown]
# explore the OS module.

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Documents'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### import data

# %%
data_train = pd.read_csv('california_housing_train.csv')

data_test = pd.read_csv('california_housing_test.csv')

# %%
data_train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# #### 1. What is the distribution of median house values?

# %%
# Analyze the range, mean, and distribution of the 'median_house_value' column 
# to understand the overall pricing trend. How does the median income correlate with the median house value?


hsv.describe()
# Out:
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %%
# isolate median_house_values in dataframe and plot usng seaborn or matplotlib. 

hsv = pd.DataFrame(data_train['median_house_value'])

print('median house value snapshot and distribution plot: ', hsv.head())

sns.histplot(hsv, kde=True)
# Out:
# median house value snapshot and distribution plot:     median_house_value
# 0             66900.0
# 1             80100.0
# 2             85700.0
# 3             73400.0
# 4             65500.0
# <Axes: ylabel='Count'>

# %%
sns.displot(hsv, kde=True)

# %%
plt.plot(hsv)

# %%
mi_hsv = pd.DataFrame(data_train[['median_income', 'median_house_value']])

# %% [markdown]
# #### 2.  Investigate the relationship between 'median_income' and 'median_house_value' to understand if higher incomes correspond to higher house values. Which areas have the highest and lowest median house values?

# %%
help(pd.DataFrame.corr(__self__))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 help(pd.DataFrame.corr(__self__))
#
# NameError: name '__self__' is not defined

# %%
print("correlation: ", pd.DataFrame.corr(mi_hsv))
# Out:
# correlation:                      median_income  median_house_value
# median_income            1.000000            0.691871
# median_house_value       0.691871            1.000000

# %%
# isolate both columns of interest

mi_hsv = pd.DataFrame(data_train[['median_income', 'median_house_value']])

print("datasnapshot:  ", mi_hsv.head())

print("correlation: ", pd.DataFrame.corr(mi_hsv))

#sns.scatter(mi_hsv)

plt.scatter(mi_hsv['median_income'], mi_hsv['median_house_value'])

plt.xlabel('median_income')
plt.ylabel('median_house_value')

plt.title('Relationship between median_income and median_house_value, we can see the symbiotic pattern between increase in a Township median income and median house value.' )
# Out:
# datasnapshot:      median_income  median_house_value
# 0         1.4936             66900.0
# 1         1.8200             80100.0
# 2         1.6509             85700.0
# 3         3.1917             73400.0
# 4         1.9250             65500.0
# Text(0.5, 1.0, 'Relationship between median_income and median_house_value, we can see the symbiotic pattern between increase in a Township median income and median house value.')

# %% [markdown]
# #### 4. Identify geographical regions with the highest and lowest median house values by analyzing 'longitude' and 'latitude'. Is there a correlation between housing age and median house value?

# %% [markdown]
# #### 5. Explore if there's a relationship between 'housing_median_age' and 'median_house_value' to determine if newer or older houses tend to have higher values. How does the housing density (population per household) vary across different regions?

# %%
# isolate both columns of interest

ma_hsv = pd.DataFrame(data_train[['housing_median_age', 'median_house_value']])

print("datasnapshot:  ", ma_hsv.head())

#print("correlation: ", pd.cor(mi_hsv))


plt.scatter(ma_hsv['housing_median_age'], ma_hsv['median_house_value'])

plt.xlabel('median_age')
plt.ylabel('median_house_value')

plt.title('Relationship between housing_median_age and median_house_value, we can see the pattern between increase in a Township housing median age and median house value.' )
# Out:
# datasnapshot:      housing_median_age  median_house_value
# 0                15.0             66900.0
# 1                19.0             80100.0
# 2                17.0             85700.0
# 3                14.0             73400.0
# 4                20.0             65500.0
# Text(0.5, 1.0, 'Relationship between housing_median_age and median_house_value, we can see the pattern between increase in a Township housing median age and median house value.')

# %%
plt.plot(ma_hsv['housing_median_age'], ma_hsv['median_house_value'])

# %%
sns.displot(ma_hsv)
sns.title('see work')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 2
#       1 sns.displot(ma_hsv)
# ----> 2 sns.title('see work')
#
# AttributeError: module 'seaborn' has no attribute 'title'

# %% [markdown]
# #### 6. Calculate the housing density by dividing 'population' by 'households' and analyze its distribution across different areas. What is the correlation between the number of rooms and median house value?

# %%
# housing_density = df.population/df.households

# sns.displot(housing_density)

# number_of_rooms vs median_house_value. correlation

# isolate the columns of interest. 

df_6 = pd.DataFrame(data_train[['population', 'households', 'median_house_value', 'total_rooms']])

df_6.head()
# Out:
#    population  households  median_house_value  total_rooms
# 0      1015.0       472.0             66900.0       5612.0
# 1      1129.0       463.0             80100.0       7650.0
# 2       333.0       117.0             85700.0        720.0
# 3       515.0       226.0             73400.0       1501.0
# 4       624.0       262.0             65500.0       1454.0

# %%
df_6['housing_density'] = df_6['population']/df_6['households']

df_6.head()
# Out:
#    population  households  median_house_value  total_rooms  housing_density
# 0      1015.0       472.0             66900.0       5612.0         2.150424
# 1      1129.0       463.0             80100.0       7650.0         2.438445
# 2       333.0       117.0             85700.0        720.0         2.846154
# 3       515.0       226.0             73400.0       1501.0         2.278761
# 4       624.0       262.0             65500.0       1454.0         2.381679

# %%
sns.displot(df_6['housing_density'])

# %%
df_6['housing_density'].describe()
# Out:
# count    17000.000000
# mean         2.976337
# std          4.037838
# min          0.692308
# 25%          2.432609
# 50%          2.816872
# 75%          3.279435
# max        502.461538
# Name: housing_density, dtype: float64

# %%
# room_value calculation

df_6_rv = df_6[['total_rooms', 'median_house_value']]

df_6_rv.head()
# Out:
#    total_rooms  median_house_value
# 0       5612.0             66900.0
# 1       7650.0             80100.0
# 2        720.0             85700.0
# 3       1501.0             73400.0
# 4       1454.0             65500.0

# %%
plt.plot(df_6_rv)

# %%
plt.scatter(df_6_rv['total_rooms'], df_6_rv['median_house_value'])

# %%
print('correlation between total rooms and house value')
    
pd.DataFrame(df_6_rv).corr()
# Out:
# correlation between total rooms and house value
#                     total_rooms  median_house_value
# total_rooms            1.000000            0.130991
# median_house_value     0.130991            1.000000

# %%
sns.displot(df_6_rv['median_house_value'])

sns.displot(df_6_rv['median_house_value'])

# %%
sns.displot(df_6_rv['total_rooms'])

# %%
hex = pd.DataFrame(df_6_rv['median_house_value'])
hex.describe()
# Out:
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %%
hex2 = pd.DataFrame(df_6_rv['total_rooms'])
hex2.describe()
# Out:
#         total_rooms
# count  17000.000000
# mean    2643.664412
# std     2179.947071
# min        2.000000
# 25%     1462.000000
# 50%     2127.000000
# 75%     3151.250000
# max    37937.000000

# %% [markdown]
# #### 7. Investigate if 'total_rooms' has a correlation with 'median_house_value' to understand how the size of the houses influences their values. Are there any patterns in the distribution of total bedrooms and total rooms?

# %%
print('correlation between total rooms and house value')
    
pd.DataFrame(df_6_rv).corr()
# Out:
# correlation between total rooms and house value
#                     total_rooms  median_house_value
# total_rooms            1.000000            0.130991
# median_house_value     0.130991            1.000000

# %%
plt.scatter(df_6_rv['total_rooms'], df_6_rv['median_house_value'])

# %% [markdown]
# #### 8. Examine if there's a consistent ratio or pattern between 'total_bedrooms' and 'total_rooms' across different houses. How does the population relate to housing density?

# %% [markdown]
# #### 9. Explore the relationship between 'population' and the housing density to understand if higher population areas have higher or lower housing density.

# %%
pop_hd = df_6[['population', 'housing_density']]

pop_hd.head()
# Out:
#    population  housing_density
# 0      1015.0         2.150424
# 1      1129.0         2.438445
# 2       333.0         2.846154
# 3       515.0         2.278761
# 4       624.0         2.381679

# %%
sns.displot(pop_hd)

# %%
plt.scatter(pop_hd.population, pop_hd.housing_density)

# %%
hex3 = pd.DataFrame(pop_hd)
print('correlaton for populaton and housing_density')
hex3.corr()
# Out:
# correlaton for populaton and housing_density
#                  population  housing_density
# population         1.000000         0.076362
# housing_density    0.076362         1.000000

# %%
df_6.head()
# Out:
#    population  households  median_house_value  total_rooms  housing_density
# 0      1015.0       472.0             66900.0       5612.0         2.150424
# 1      1129.0       463.0             80100.0       7650.0         2.438445
# 2       333.0       117.0             85700.0        720.0         2.846154
# 3       515.0       226.0             73400.0       1501.0         2.278761
# 4       624.0       262.0             65500.0       1454.0         2.381679

# %% [markdown]
# #### 10. What is the overall distribution of housing ages in the dataset?

# %%
data_train.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
hsa = data_train[['housing_median_age', 'longitude', 'latitude']]

hsa.head()
# Out:
#    housing_median_age  longitude  latitude
# 0                15.0    -114.31     34.19
# 1                19.0    -114.47     34.40
# 2                17.0    -114.56     33.69
# 3                14.0    -114.57     33.64
# 4                20.0    -114.57     33.57

# %% [markdown]
# #### 11. Visualize the distribution of 'housing_median_age' to identify common age ranges for houses in the dataset. Is there a correlation between location (longitude and latitude) and housing features/values?

# %%
sns.displot(hsa)

# %%
hsa2 = pd.DataFrame(hsa)

hsa2.corr()
# Out:
#                     housing_median_age  longitude  latitude
# housing_median_age            1.000000  -0.114250  0.016454
# longitude                    -0.114250   1.000000 -0.925208
# latitude                      0.016454  -0.925208  1.000000

# %% [markdown]
# #### 12. Analyze if specific regions (defined by 'longitude' and 'latitude') exhibit particular housing characteristics or values. These questions can serve as a starting point for your project and help you gain insights into various aspects of the California housing market.

# %%
### see if you can perform binning in the values for longitude and latitude, or other continuous variables. 

##

# %%
## goal to visualze on a map, the coordinates being explored.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_train.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %%
# plotting correlation heatmap 
dataplot = sns.heatmap(data_train.corr(), cmap="YlGnBu", annot=True) 
  
# displaying heatmap 
plt.show()

# %% [markdown]
# we can see that median_house_value has a 0.061 correllation with population,
#
# the value represents a weak relatonship, we will expose this weakness with graphs and compare the same plots to a strong relationship visually

# %%
#data_exp2 = data_train[['median_house_value'],['populaton']]

z1 = data_train['median_house_value']
z2 = data_train['population']

# %%
plt.plot(z1,z2)
plt.xlabel = 'population'
plt.ylabel = 'median house value'
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
plt.scatter(z1,z2)

# %% [markdown]
# we can see that median_income has a 0.69 correllation with house_value,
# so I think it is important to create visuals for that.

# %%
pd_exp = data_train[['median_house_value','median_income' ]]
pd_exp.head(10)
# Out:
#    median_house_value  median_income
# 0             66900.0         1.4936
# 1             80100.0         1.8200
# 2             85700.0         1.6509
# 3             73400.0         3.1917
# 4             65500.0         1.9250
# 5             74000.0         3.3438
# 6             82400.0         2.6768
# 7             48500.0         1.7083
# 8             58400.0         2.1782
# 9             48100.0         2.1908

# %%
x = pd_exp[['median_house_value']]
y =  pd_exp[['median_income']]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
sns.regplot(x=pd_exp['median_house_value'], y=pd_exp['median_income'], data=pd_exp)
plt.show()

# %%
pd_exp.lin

# %%
a = (1/6)**5
print(a)
# Out:
# 0.00012860082304526745

# %%
# Step 2: Plot the distribution using matplotlib
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
hsv.value_counts().plot(kind='bar')  # Plotting the counts of each entity
plt.title('Distribution of Entity')
plt.xlabel('Entity')
plt.ylabel('Frequency')
plt.show()
